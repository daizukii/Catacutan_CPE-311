# %% [markdown]
# **Hands-on Activity 2.1: The Tower of Hanoi Problem** <br>
# Catacutan, Anna Faith A. <br>
# CPE22S3 <br>
# January 8, 2026

# %%
def TowerOfHanoi(n, source, auxiliary, destination):
  if n == 1:
    disk = source.pop()
    destination.append(disk)
    print(f"Move Disk {disk}")
    state()
    return

  TowerOfHanoi(n - 1, source, destination, auxiliary)
  disk = source.pop()
  destination.append(disk)
  print(f"Move Disk {disk}")
  state()

  TowerOfHanoi(n - 1, auxiliary, source, destination)

def state():
  print(f"A: {source}")
  print(f"B: {auxiliary}")
  print(f"C: {destination}\n")

source = [14, 11, 8, 5]
auxiliary = []
destination = []

TowerOfHanoi(len(source), source, auxiliary, destination)
# Out:
# Move Disk 5
# A: [14, 11, 8]
# B: [5]
# C: []
#
# Move Disk 8
# A: [14, 11]
# B: [5]
# C: [8]
#
# Move Disk 5
# A: [14, 11]
# B: []
# C: [8, 5]
#
# Move Disk 11
# A: [14]
# B: [11]
# C: [8, 5]
#
# Move Disk 5
# A: [14, 5]
# B: [11]
# C: [8]
#
# Move Disk 8
# A: [14, 5]
# B: [11, 8]
# C: []
#
# Move Disk 5
# A: [14]
# B: [11, 8, 5]
# C: []
#
# Move Disk 14
# A: []
# B: [11, 8, 5]
# C: [14]
#
# Move Disk 5
# A: []
# B: [11, 8]
# C: [14, 5]
#
# Move Disk 8
# A: [8]
# B: [11]
# C: [14, 5]
#
# Move Disk 5
# A: [8, 5]
# B: [11]
# C: [14]
#
# Move Disk 11
# A: [8, 5]
# B: []
# C: [14, 11]
#
# Move Disk 5
# A: [8]
# B: [5]
# C: [14, 11]
#
# Move Disk 8
# A: []
# B: [5]
# C: [14, 11, 8]
#
# Move Disk 5
# A: []
# B: []
# C: [14, 11, 8, 5]

# %% [markdown]
# **Observations of the algorithm/solution:**<br>
# While doing this actvity, i have observed that the program has successfully executed a solution that perfectly follows the rules of the tower of hanoi. I have observed that as I increase the number of disks to the source peg, the number of moves needed to solve the problem increases along with it.
#
# **Supplementary Activity:**<br>
# 1. The programming technique that I have implemented for this activity is the recursion programming technique. This technique is the repetitive calling of a single function to solve the problem. As one can see on the code, the function TowerOfHanoi was called multiple times. The first recursion was used to move the first three disks from the source peg to the auxiliary peg. The second recursion was used to move the disks in the auxiliary peg to the destination peg.
# 2.
# ![Screenshot 2026-01-08 132120.png](data:image/png;base64,...)
#
# This is the base case of my recurision. This stops the recursive function and makes it finite.
#
# ![Screenshot 2026-01-08 132636.png](data:image/png;base64,...)
#
# This is the first time recursion was used. This is done to move the first three disks into the auxiliary peg.
#
# ![Screenshot 2026-01-08 132643.png](data:image/png;base64,...)
#
# This second recursion was used to move the disks on the auxiliary peg to the destination peg.
#
# **Conclusion:** <br>
# I was initially puzzled about how to start this activity. I had an idea in mind but I wasn't sure about how I will be implementing that into a tower of hanoi problem. I had decided to first start by looking for solutions that other people made online. This enabled me to know a way that this challenge can be solved. Most of the programs available online simply lists the moves being done. With that in mind, I have decided to add my own little twist into the solution by using a list instead and printing the contents of each peg. This acitvity has enabled me to learn even more about the tower of hanoi. I had a lot of fun learning how to solve it using codes. This was a challenging yet fun activity. The process was hard—specially the debugging—but seing the product of my hardwork was truly a sweet reward. I am looking forward to learning more in the future activities and honing the skills that I have gained along the way.
